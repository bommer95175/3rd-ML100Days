# %% [markdown]
# ## Work
# 1. 試改變 monitor "Validation Accuracy" 並比較結果
# 2. 調整 earlystop 的等待次數至 10, 25 並比較結果

# %%
import os
import keras
import matplotlib.pyplot as plt
# %matplotlib inline


# Disable GPU
os.environ["CUDA_VISIBLE_DEVICES"] = ""
# Out:
# Using TensorFlow backend.

# %%
train, test = keras.datasets.cifar10.load_data()

# %%
## 資料前處理
def preproc_x(x, flatten=True):
    x = x / 255.
    if flatten:
        x = x.reshape((len(x), -1))
    return x

def preproc_y(y, num_classes=10):
    if y.shape[-1] == 1:
        y = keras.utils.to_categorical(y, num_classes)
    return y

# %%
x_train, y_train = train
x_test, y_test = test

# Preproc the inputs
x_train = preproc_x(x_train)
x_test = preproc_x(x_test)

# Preprc the outputs
y_train = preproc_y(y_train)
y_test = preproc_y(y_test)

# %%
from keras.layers import BatchNormalization
def build_mlp(input_shape, output_units=10, num_neurons=[512, 256, 128]):
    input_layer = keras.layers.Input(input_shape)
    
    for i, n_units in enumerate(num_neurons):
        if i == 0:
            x = keras.layers.Dense(units=n_units, 
                                   activation="relu", 
                                   name="hidden_layer"+str(i+1))(input_layer)
            x = BatchNormalization()(x)
        else:
            x = keras.layers.Dense(units=n_units, 
                                   activation="relu", 
                                   name="hidden_layer"+str(i+1))(x)
            x = BatchNormalization()(x)
    
    out = keras.layers.Dense(units=output_units, activation="softmax", name="output")(x)
    
    model = keras.models.Model(inputs=[input_layer], outputs=[out])
    return model

# %%
LEARNING_RATE = 1e-3
EPOCHS = 50
BATCH_SIZE = 1024
MOMENTUM = 0.95

# %%
from keras.callbacks import EarlyStopping
i=10
earlystop = EarlyStopping(monitor="val_accuracy", 
                          patience=i, 
                          verbose=1
                          )

results = {}

model = build_mlp(input_shape=x_train.shape[1:])
model.summary()
optimizer = keras.optimizers.SGD(lr=LEARNING_RATE, nesterov=True, momentum=MOMENTUM)
model.compile(loss="categorical_crossentropy", metrics=["accuracy"], optimizer=optimizer)

model.fit(x_train, y_train, 
              epochs=EPOCHS, 
              batch_size=BATCH_SIZE, 
              validation_data=(x_test, y_test), 
              shuffle=True,
              callbacks=[earlystop]
             )

# Collect results
train_loss = model.history.history["loss"]
valid_loss = model.history.history["val_loss"]
train_acc = model.history.history["accuracy"]
valid_acc = model.history.history["val_accuracy"]

exp_name_tag = "exp-accu_earlystop_%s" %str(i)
results[exp_name_tag] = {'train-loss': train_loss,
                             'valid-loss': valid_loss,
                             'train-acc': train_acc,
                             'valid-acc': valid_acc}
i=25
earlystop = EarlyStopping(monitor="val_accuracy", 
                          patience=i, 
                          verbose=1
                          )

model = build_mlp(input_shape=x_train.shape[1:])
model.summary()
optimizer = keras.optimizers.SGD(lr=LEARNING_RATE, nesterov=True, momentum=MOMENTUM)
model.compile(loss="categorical_crossentropy", metrics=["accuracy"], optimizer=optimizer)

model.fit(x_train, y_train, 
              epochs=EPOCHS, 
              batch_size=BATCH_SIZE, 
              validation_data=(x_test, y_test), 
              shuffle=True,
              callbacks=[earlystop]
             )

# Collect results
train_loss = model.history.history["loss"]
valid_loss = model.history.history["val_loss"]
train_acc = model.history.history["accuracy"]
valid_acc = model.history.history["val_accuracy"]

exp_name_tag = "exp-accu_earlystop_%s" %str(i)
results[exp_name_tag] = {'train-loss': train_loss,
                             'valid-loss': valid_loss,
                             'train-acc': train_acc,
                             'valid-acc': valid_acc}
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 512)               2048
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 256)               1024
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 128)               512
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,742,474
# Trainable params: 1,740,682
# Non-trainable params: 1,792
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/50
# 50000/50000 [==============================] - 5s 107us/step - loss: 2.2162 - accuracy: 0.2718 - val_loss: 2.1502 - val_accuracy: 0.1817
# Epoch 2/50
# 50000/50000 [==============================] - 4s 87us/step - loss: 1.7385 - accuracy: 0.3963 - val_loss: 1.9638 - val_accuracy: 0.2989
# Epoch 3/50
# 50000/50000 [==============================] - 4s 84us/step - loss: 1.6151 - accuracy: 0.4358 - val_loss: 1.8258 - val_accuracy: 0.3575
# Epoch 4/50
# 50000/50000 [==============================] - 4s 83us/step - loss: 1.5417 - accuracy: 0.4632 - val_loss: 1.7088 - val_accuracy: 0.4063
# Epoch 5/50
# 50000/50000 [==============================] - 4s 84us/step - loss: 1.4874 - accuracy: 0.4809 - val_loss: 1.6448 - val_accuracy: 0.4248
# Epoch 6/50
# 50000/50000 [==============================] - 4s 83us/step - loss: 1.4432 - accuracy: 0.4964 - val_loss: 1.5897 - val_accuracy: 0.4395
# Epoch 7/50
# 50000/50000 [==============================] - 4s 85us/step - loss: 1.4047 - accuracy: 0.5111 - val_loss: 1.5540 - val_accuracy: 0.4506
# Epoch 8/50
# 50000/50000 [==============================] - 4s 84us/step - loss: 1.3684 - accuracy: 0.5237 - val_loss: 1.5303 - val_accuracy: 0.4603
# Epoch 9/50
# 50000/50000 [==============================] - 4s 84us/step - loss: 1.3353 - accuracy: 0.5358 - val_loss: 1.5058 - val_accuracy: 0.4656
# Epoch 10/50
# 50000/50000 [==============================] - 4s 84us/step - loss: 1.3069 - accuracy: 0.5465 - val_loss: 1.5161 - val_accuracy: 0.4638
# Epoch 11/50
# 50000/50000 [==============================] - 4s 84us/step - loss: 1.2786 - accuracy: 0.5589 - val_loss: 1.4981 - val_accuracy: 0.4697
# Epoch 12/50
# 50000/50000 [==============================] - 4s 84us/step - loss: 1.2497 - accuracy: 0.5661 - val_loss: 1.4821 - val_accuracy: 0.4729
# Epoch 13/50
# 50000/50000 [==============================] - 4s 83us/step - loss: 1.2245 - accuracy: 0.5752 - val_loss: 1.4644 - val_accuracy: 0.4827
# Epoch 14/50
# 50000/50000 [==============================] - 4s 83us/step - loss: 1.1984 - accuracy: 0.5871 - val_loss: 1.4714 - val_accuracy: 0.4787
# Epoch 15/50
# 50000/50000 [==============================] - 4s 83us/step - loss: 1.1742 - accuracy: 0.5958 - val_loss: 1.4618 - val_accuracy: 0.4881
# Epoch 16/50
# 50000/50000 [==============================] - 4s 83us/step - loss: 1.1512 - accuracy: 0.6040 - val_loss: 1.4771 - val_accuracy: 0.4793
# Epoch 17/50
# 50000/50000 [==============================] - 4s 85us/step - loss: 1.1285 - accuracy: 0.6133 - val_loss: 1.4633 - val_accuracy: 0.4823
# Epoch 18/50
# 50000/50000 [==============================] - 4s 83us/step - loss: 1.1064 - accuracy: 0.6204 - val_loss: 1.4667 - val_accuracy: 0.4829
# Epoch 19/50
# 50000/50000 [==============================] - 4s 84us/step - loss: 1.0840 - accuracy: 0.6295 - val_loss: 1.4757 - val_accuracy: 0.4853
# Epoch 20/50
# 50000/50000 [==============================] - 4s 83us/step - loss: 1.0607 - accuracy: 0.6398 - val_loss: 1.4608 - val_accuracy: 0.4882
# Epoch 21/50
# 50000/50000 [==============================] - 4s 84us/step - loss: 1.0420 - accuracy: 0.6446 - val_loss: 1.4683 - val_accuracy: 0.4828
# Epoch 22/50
# 50000/50000 [==============================] - 4s 83us/step - loss: 1.0175 - accuracy: 0.6554 - val_loss: 1.4703 - val_accuracy: 0.4895
# Epoch 23/50
# 50000/50000 [==============================] - 4s 84us/step - loss: 0.9986 - accuracy: 0.6628 - val_loss: 1.4699 - val_accuracy: 0.4911
# Epoch 24/50
# 50000/50000 [==============================] - 4s 84us/step - loss: 0.9778 - accuracy: 0.6706 - val_loss: 1.4946 - val_accuracy: 0.4813
# Epoch 25/50
# 50000/50000 [==============================] - 4s 84us/step - loss: 0.9529 - accuracy: 0.6808 - val_loss: 1.4807 - val_accuracy: 0.4893
# Epoch 26/50
# 50000/50000 [==============================] - 4s 84us/step - loss: 0.9354 - accuracy: 0.6863 - val_loss: 1.4848 - val_accuracy: 0.4838
# Epoch 27/50
# 50000/50000 [==============================] - 4s 84us/step - loss: 0.9148 - accuracy: 0.6946 - val_loss: 1.4805 - val_accuracy: 0.4902
# Epoch 28/50
# 50000/50000 [==============================] - 4s 85us/step - loss: 0.8924 - accuracy: 0.7035 - val_loss: 1.4841 - val_accuracy: 0.4900
# Epoch 29/50
# 50000/50000 [==============================] - 4s 84us/step - loss: 0.8739 - accuracy: 0.7118 - val_loss: 1.4908 - val_accuracy: 0.4905
# Epoch 30/50
# 50000/50000 [==============================] - 4s 84us/step - loss: 0.8540 - accuracy: 0.7190 - val_loss: 1.5084 - val_accuracy: 0.4850
# Epoch 31/50
# 50000/50000 [==============================] - 4s 85us/step - loss: 0.8334 - accuracy: 0.7267 - val_loss: 1.5123 - val_accuracy: 0.4886
# Epoch 32/50
# 50000/50000 [==============================] - 4s 84us/step - loss: 0.8134 - accuracy: 0.7354 - val_loss: 1.5113 - val_accuracy: 0.4867
# Epoch 33/50
# 50000/50000 [==============================] - 4s 84us/step - loss: 0.7952 - accuracy: 0.7418 - val_loss: 1.5192 - val_accuracy: 0.4864
# Epoch 00033: early stopping
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 512)               2048
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 256)               1024
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 128)               512
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,742,474
# Trainable params: 1,740,682
# Non-trainable params: 1,792
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/50
# 50000/50000 [==============================] - 5s 93us/step - loss: 2.2187 - accuracy: 0.2697 - val_loss: 2.1858 - val_accuracy: 0.1493
# Epoch 2/50
# 50000/50000 [==============================] - 4s 85us/step - loss: 1.7407 - accuracy: 0.3944 - val_loss: 2.0171 - val_accuracy: 0.2572
# Epoch 3/50
# 50000/50000 [==============================] - 4s 84us/step - loss: 1.6154 - accuracy: 0.4364 - val_loss: 1.8522 - val_accuracy: 0.3459
# Epoch 4/50
# 50000/50000 [==============================] - 4s 84us/step - loss: 1.5433 - accuracy: 0.4611 - val_loss: 1.7386 - val_accuracy: 0.3942
# Epoch 5/50
# 50000/50000 [==============================] - 4s 84us/step - loss: 1.4890 - accuracy: 0.4807 - val_loss: 1.6564 - val_accuracy: 0.4217
# Epoch 6/50
# 50000/50000 [==============================] - 4s 84us/step - loss: 1.4428 - accuracy: 0.4965 - val_loss: 1.5905 - val_accuracy: 0.4337
# Epoch 7/50
# 50000/50000 [==============================] - 4s 84us/step - loss: 1.4049 - accuracy: 0.5098 - val_loss: 1.5628 - val_accuracy: 0.4495
# Epoch 8/50
# 50000/50000 [==============================] - 4s 84us/step - loss: 1.3695 - accuracy: 0.5230 - val_loss: 1.5285 - val_accuracy: 0.4568
# Epoch 9/50
# 50000/50000 [==============================] - 4s 86us/step - loss: 1.3363 - accuracy: 0.5361 - val_loss: 1.5159 - val_accuracy: 0.4612
# Epoch 10/50
# 50000/50000 [==============================] - 4s 86us/step - loss: 1.3066 - accuracy: 0.5445 - val_loss: 1.5094 - val_accuracy: 0.4644
# Epoch 11/50
# 50000/50000 [==============================] - 4s 86us/step - loss: 1.2787 - accuracy: 0.5572 - val_loss: 1.4931 - val_accuracy: 0.4697
# Epoch 12/50
# 50000/50000 [==============================] - 5s 92us/step - loss: 1.2522 - accuracy: 0.5662 - val_loss: 1.4885 - val_accuracy: 0.4752
# Epoch 13/50
# 50000/50000 [==============================] - 4s 89us/step - loss: 1.2247 - accuracy: 0.5783 - val_loss: 1.4881 - val_accuracy: 0.4753
# Epoch 14/50
# 50000/50000 [==============================] - 4s 85us/step - loss: 1.2010 - accuracy: 0.5871 - val_loss: 1.4757 - val_accuracy: 0.4772
# Epoch 15/50
# 50000/50000 [==============================] - 4s 86us/step - loss: 1.1744 - accuracy: 0.5956 - val_loss: 1.4703 - val_accuracy: 0.4850
# Epoch 16/50
# 50000/50000 [==============================] - 4s 84us/step - loss: 1.1519 - accuracy: 0.6044 - val_loss: 1.4624 - val_accuracy: 0.4877
# Epoch 17/50
# 50000/50000 [==============================] - 4s 84us/step - loss: 1.1290 - accuracy: 0.6123 - val_loss: 1.4570 - val_accuracy: 0.4889
# Epoch 18/50
# 50000/50000 [==============================] - 4s 85us/step - loss: 1.1060 - accuracy: 0.6217 - val_loss: 1.4665 - val_accuracy: 0.4846
# Epoch 19/50
# 50000/50000 [==============================] - 4s 85us/step - loss: 1.0848 - accuracy: 0.6302 - val_loss: 1.4531 - val_accuracy: 0.4930
# Epoch 20/50
# 50000/50000 [==============================] - 4s 85us/step - loss: 1.0629 - accuracy: 0.6369 - val_loss: 1.4655 - val_accuracy: 0.4893
# Epoch 21/50
# 50000/50000 [==============================] - 4s 84us/step - loss: 1.0420 - accuracy: 0.6456 - val_loss: 1.4487 - val_accuracy: 0.4942
# Epoch 22/50
# 50000/50000 [==============================] - 4s 84us/step - loss: 1.0196 - accuracy: 0.6532 - val_loss: 1.4607 - val_accuracy: 0.4922
# Epoch 23/50
# 50000/50000 [==============================] - 4s 84us/step - loss: 0.9991 - accuracy: 0.6614 - val_loss: 1.4562 - val_accuracy: 0.4952
# Epoch 24/50
# 50000/50000 [==============================] - 4s 85us/step - loss: 0.9792 - accuracy: 0.6683 - val_loss: 1.4630 - val_accuracy: 0.4944
# Epoch 25/50
# 50000/50000 [==============================] - 4s 85us/step - loss: 0.9575 - accuracy: 0.6776 - val_loss: 1.4628 - val_accuracy: 0.4962
# Epoch 26/50
# 50000/50000 [==============================] - 5s 99us/step - loss: 0.9384 - accuracy: 0.6857 - val_loss: 1.4707 - val_accuracy: 0.4932
# Epoch 27/50
# 50000/50000 [==============================] - 4s 88us/step - loss: 0.9176 - accuracy: 0.6940 - val_loss: 1.4593 - val_accuracy: 0.4992
# Epoch 28/50
# 50000/50000 [==============================] - 5s 92us/step - loss: 0.8974 - accuracy: 0.7002 - val_loss: 1.4975 - val_accuracy: 0.4882
# Epoch 29/50
# 50000/50000 [==============================] - 5s 103us/step - loss: 0.8770 - accuracy: 0.7084 - val_loss: 1.4741 - val_accuracy: 0.4926
# Epoch 30/50
# 50000/50000 [==============================] - 5s 102us/step - loss: 0.8572 - accuracy: 0.7163 - val_loss: 1.4818 - val_accuracy: 0.4985
# Epoch 31/50
# 50000/50000 [==============================] - 5s 110us/step - loss: 0.8380 - accuracy: 0.7220 - val_loss: 1.4870 - val_accuracy: 0.4933
# Epoch 32/50
# 50000/50000 [==============================] - 6s 113us/step - loss: 0.8189 - accuracy: 0.7307 - val_loss: 1.5057 - val_accuracy: 0.4906
# Epoch 33/50
# 50000/50000 [==============================] - 6s 122us/step - loss: 0.7989 - accuracy: 0.7386 - val_loss: 1.5055 - val_accuracy: 0.4945
# Epoch 34/50
# 50000/50000 [==============================] - 5s 100us/step - loss: 0.7801 - accuracy: 0.7471 - val_loss: 1.5038 - val_accuracy: 0.4911
# Epoch 35/50
# 50000/50000 [==============================] - 5s 106us/step - loss: 0.7602 - accuracy: 0.7550 - val_loss: 1.5132 - val_accuracy: 0.4942
# Epoch 36/50
# 50000/50000 [==============================] - 4s 89us/step - loss: 0.7411 - accuracy: 0.7620 - val_loss: 1.5122 - val_accuracy: 0.5009
# Epoch 37/50
# 50000/50000 [==============================] - 4s 89us/step - loss: 0.7207 - accuracy: 0.7715 - val_loss: 1.5237 - val_accuracy: 0.4938
# Epoch 38/50
# 50000/50000 [==============================] - 5s 92us/step - loss: 0.7044 - accuracy: 0.7771 - val_loss: 1.5568 - val_accuracy: 0.4904
# Epoch 39/50
# 50000/50000 [==============================] - 4s 89us/step - loss: 0.6860 - accuracy: 0.7845 - val_loss: 1.5612 - val_accuracy: 0.4949
# Epoch 40/50
# 50000/50000 [==============================] - 4s 87us/step - loss: 0.6664 - accuracy: 0.7925 - val_loss: 1.5754 - val_accuracy: 0.4895
# Epoch 41/50
# 50000/50000 [==============================] - 4s 89us/step - loss: 0.6472 - accuracy: 0.8002 - val_loss: 1.5630 - val_accuracy: 0.4932
# Epoch 42/50
# 50000/50000 [==============================] - 4s 89us/step - loss: 0.6285 - accuracy: 0.8082 - val_loss: 1.5722 - val_accuracy: 0.4905
# Epoch 43/50
# 50000/50000 [==============================] - 4s 84us/step - loss: 0.6106 - accuracy: 0.8146 - val_loss: 1.6027 - val_accuracy: 0.4918
# Epoch 44/50
# 50000/50000 [==============================] - 5s 95us/step - loss: 0.5928 - accuracy: 0.8231 - val_loss: 1.6047 - val_accuracy: 0.4943
# Epoch 45/50
# 50000/50000 [==============================] - 5s 110us/step - loss: 0.5752 - accuracy: 0.8298 - val_loss: 1.6003 - val_accuracy: 0.4915
# Epoch 46/50
# 50000/50000 [==============================] - 5s 95us/step - loss: 0.5596 - accuracy: 0.8344 - val_loss: 1.6309 - val_accuracy: 0.4937
# Epoch 47/50
# 50000/50000 [==============================] - 5s 94us/step - loss: 0.5406 - accuracy: 0.8419 - val_loss: 1.6164 - val_accuracy: 0.4928
# Epoch 48/50
# 50000/50000 [==============================] - 5s 98us/step - loss: 0.5242 - accuracy: 0.8483 - val_loss: 1.6480 - val_accuracy: 0.4850
# Epoch 49/50
# 50000/50000 [==============================] - 5s 103us/step - loss: 0.5084 - accuracy: 0.8556 - val_loss: 1.6732 - val_accuracy: 0.4822
# Epoch 50/50
# 50000/50000 [==============================] - 5s 105us/step - loss: 0.4918 - accuracy: 0.8623 - val_loss: 1.6965 - val_accuracy: 0.4826

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
color_bar = ["r", "g", "b", "y", "m", "k","r", "g", "b", "y", "m", "k","r", "g", "b", "y", "m", "k"]

plt.figure(figsize=(20,14))
for i, cond in enumerate(results.keys()):
    plt.plot(range(len(results[cond]['train-loss'])),results[cond]['train-loss'], '-', label=cond, color=color_bar[i])
    plt.plot(range(len(results[cond]['valid-loss'])),results[cond]['valid-loss'], '--', label=cond, color=color_bar[i])
plt.title("Loss")
plt.ylim([0, 5])
plt.legend()
plt.show()

plt.figure(figsize=(20,14))
for i, cond in enumerate(results.keys()):
    plt.plot(range(len(results[cond]['train-acc'])),results[cond]['train-acc'], '-', label=cond, color=color_bar[i])
    plt.plot(range(len(results[cond]['valid-acc'])),results[cond]['valid-acc'], '--', label=cond, color=color_bar[i])
plt.title("Accuracy")
plt.legend()
plt.show()
